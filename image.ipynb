# %% [markdown]
# ## Image Processing in Python with Scikit Image

# %%
from skimage import data,io
from matplotlib import pyplot as plt
rocket_image= data.rocket()
io.imshow(rocket_image)
plt.show()

# %%
from skimage import color
grayscale=color.rgb2gray(rocket_image)
io.imshow(grayscale)

# %%
from skimage import color
colorimage= color.gray2rgb(rocket_image)
io.imshow(rocket_image)
# Out:
# C:\Users\TOWHID~1\AppData\Local\Temp/ipykernel_6092/3608958726.py:2: FutureWarning: Pass-through of possibly RGB images in gray2rgb is deprecated. In version 0.19, input arrays will always be considered grayscale, even if the last dimension has length 3 or 4. To prevent this warning and ensure compatibility with future versions, detect RGB images outside of this function.
#   colorimage= color.gray2rgb(rocket_image)

# %%
# defined function to show image
def show_image(image, title="image",cmap_type="gray"):
    plt.imshow(image,cmap=cmap_type)
    plt.title(title)
    plt.axis('off')
    plt.show()
show_image(grayscale,"Grayscale")
show_image(rocket_image,"rocket-image")

# %%
# compare color & size
import numpy as np
image= np.array(grayscale)
print(image.shape)
image_color=np.array(rocket_image)
print(image_color.shape)
# Out:
# (427, 640)
# (427, 640, 3)

# %% [markdown]
# ### Numpy for images

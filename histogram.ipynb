# %% [markdown]
# ###### Image processing using NumPy

# %%
import numpy as np
from matplotlib import pyplot as plt
test_image= plt.imread('ancient.jpg')
type(test_image)
# Out:
# numpy.ndarray

# %% [markdown]
# ndarray is a multidimensional array

# %%
vertically_flipped= np.flipud(test_image)
def show_image(image, title="image",cmap_type="gray"):
    plt.imshow(image,cmap=cmap_type)
    plt.title(title)
    plt.axis('off')
    plt.show()
show_image(vertically_flipped,'vertically flipped image')

# %%
horizontally_flipped= np.fliplr(test_image)
show_image(horizontally_flipped,'horizontally flipped')

# %%
#histogram
blue= test_image[:,:,2]
plt.hist(blue.ravel(),bins=256)
plt.title("blue hisogram of image")
plt.show()

# %%
#red histogram
red=test_image[:,:,0]
plt.hist(red.ravel(),bins=256)
plt.title("red histogram")
plt.show()

# %%
#green histogram
green=test_image[:,:,1]
plt.hist(green.ravel(),bins=256)
plt.title("green histogram")
plt.show()

# %%
from skimage.filters import try_all_threshold
from skimage.filters import threshold_otsu
from skimage import color 
image=plt.imread('threshold.jpg')

image_gray = color.rgb2gray(image)

thresh = threshold_otsu(image_gray)


binary = image_gray >  thresh

show_image(image,'original image')
show_image(binary, 'Binary image')
